# %% [markdown]
# There is a real time fire dataset (Indoor_Fire_Dataset.csv) with the following description:
#
#
# The dataset contains 4 incipient fire scenarios (wood, candles, cable, lunts) along with 8 different nuisance scenarios (smoke from a fog machine, deodorant, ethanol, CO release, exhaust gases, green waste, welding, and abrasive cutting) carried out in a (10 x 22 x 8)m^3 industrial hall without ventilation. Each scenario was repeated 3 times in random with background sequences in between to reduce the influence of prehistory. The dataset consists of 248,502 rows and 18 columns and is structures as a continuous multivariate time series. Each row represents the sensor measurements (CO2, CO, H2, humidity, particulate matter of different sizes, air temperature, VOC and UV) from a unique sensor node position ("Sensor_ID") in the industrial hall at a specific timestamp. The columns correspond to the sensor measurements and include additional labels: a scenario-specific label ("scenario_label"), a binary label ("anomaly_label") distinguishing between "Normal" (background) and "Anomaly" (fire or nuisance scenario), a "fire_label" intersecting the anomalies into fire-relevant or non-fire-relevant anomalies and a progress label ("progress_label") that allows for dividing the events into sub-sequences based on ongoing physical sub-processes. The "Sensor_ID" column can be utilized to access data from different sensor node positions.

# %% [markdown]
# Our database is different, for we need to transform this data into a new csv file in order to store that into our database. Instruction for each column:
#
# 1. Temperature (float8) - same as the data column Temperature_Room
# 2. Humidity (float8) - same as the data column Humidity_Room
# 3. Pressure (float8) - keep every entry 1016.0.
# 4. CO (float8) - same as the data column CO_Room
# 5. CO2 (float8) - same as the data column CO2_Room
# 6. Fire (bool) - if the "anomaly_label" is also not 0 AND the "fire" label is not 0, the entry is True. Else, the entry is false.

# %%
import pandas as pd

# Read the Indoor_Fire_Dataset.csv file
df = pd.read_csv('Indoor_Fire_Dataset.csv')

# Apply column transformations and additions
df_transformed = pd.DataFrame({
    'Temperature': df['Temperature_Room'],
    'Humidity': df['Humidity_Room'],
    'Pressure': 1016.0,
    'CO': df['CO_Room'],
    'CO2': df['CO2_Room'],
    'Fire': (df['fire'] != 0.0) & (df['anomaly_label'] != 0.0)
})

# Save the transformed data to our_fire_data.csv
df_transformed.to_csv('our_fire_data.csv', index=False)

print("Data transformed and saved to 'our_fire_data.csv' successfully!")
# Out:
# Data transformed and saved to 'our_fire_data.csv' successfully!

# %% [markdown]
# Here are some other supervised learning models commonly used for classification tasks, each with its own strengths and weaknesses:
#
# 1.  **Decision Trees:**
#     *   **Concept:** Builds a tree-like model of decisions based on features to predict a target value. It splits data into subsets based on the value of input features.
#     *   **Pros:** Easy to understand and interpret (white-box model), can handle both numerical and categorical data, requires little data preparation.
#     *   **Cons:** Prone to overfitting, can be unstable (small variations in data might result in a completely different tree).
#
# 2.  **Random Forest:**
#     *   **Concept:** An ensemble learning method that builds multiple decision trees during training and outputs the class that is the mode of the classes (classification) or mean prediction (regression) of the individual trees.
#     *   **Pros:** Reduces overfitting compared to individual decision trees, generally more accurate and robust, can handle a large number of features.
#     *   **Cons:** Less interpretable than single decision trees, can be computationally expensive for very large datasets.
#
# 3.  **Support Vector Machines (SVM):**
#     *   **Concept:** Finds the optimal hyperplane that best separates classes in a high-dimensional space. It aims to maximize the margin between the classes.
#     *   **Pros:** Effective in high-dimensional spaces, memory efficient (uses a subset of training points in the decision function), versatile due to different kernel functions.
#     *   **Cons:** Can be slow on large datasets, choosing the right kernel function and regularization parameters can be challenging.
#
# 4.  **K-Nearest Neighbors (KNN):**
#     *   **Concept:** A non-parametric, lazy learning algorithm that classifies a data point based on the majority class of its 'k' nearest neighbors in the feature space.
#     *   **Pros:** Simple to understand and implement, no training phase (lazy learner), works well for multi-class problems.
#     *   **Cons:** Computationally expensive during prediction (has to calculate distance to all training examples), sensitive to irrelevant features and the scale of data, needs careful selection of 'k'.
#
# 5.  **Gradient Boosting (e.g., XGBoost, LightGBM, CatBoost):**
#     *   **Concept:** Builds an ensemble of weak prediction models (typically decision trees) sequentially. Each new tree corrects the errors of the previous ones.
#     *   **Pros:** Often provides state-of-the-art performance on many tabular datasets, handles various data types, robust to overfitting with proper tuning.
#     *   **Cons:** Can be more complex to tune than Random Forest, prone to overfitting if not tuned carefully, training can be time-consuming.
#
# 6.  **Neural Networks (Deep Learning):**
#     *   **Concept:** Composed of layers of interconnected nodes (neurons), inspired by the human brain. They learn hierarchical representations of data.
#     *   **Pros:** Highly powerful for complex patterns, especially in image, text, and sequence data; can achieve very high accuracy with enough data and computational resources.
#     *   **Cons:** Requires very large datasets for optimal performance, computationally intensive, difficult to interpret (black-box model), prone to overfitting without proper regularization.
#
# The choice of model depends heavily on the specific problem, the nature of the data, the size of the dataset, computational resources, and the need for interpretability.

# %% [markdown]
# The next step is to build a predictive model using Sci-Kit learn library in Python. Linear classifier is probably a good model that helps us to process the data. First we need to classify the data "our_fire_data.csv" into training data and testing data, with each dataset having True and False outputs under column "fire". The training data should be saved as training.csv and the testing data should be saved as testing.csv. Just try one line to training and the next line to testing, then again the next line to training, and so on.

# %%
import pandas as pd

# Load the transformed data
df_fire = pd.read_csv('our_fire_data.csv')

# Split into training and testing sets based on alternating rows
training_df = df_fire.iloc[::2]
testing_df = df_fire.iloc[1::2]

# Save the training and testing sets to new CSV files
training_df.to_csv('training.csv', index=False)
testing_df.to_csv('testing.csv', index=False)

print("Data successfully split into 'training.csv' and 'testing.csv'!")
# Out:
# Data successfully split into 'training.csv' and 'testing.csv'!

# %% [markdown]
# Then import the linear classification tools from Scikit-learn. These tools will be used on the five parameters: Temperature, Humidity, Pressure, CO, and CO2. The boolean value fire will be the result to be predicted. Write the import lines.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Training Part:
# Using the training.csv data, train the model to so that it would use linear classification to predict the fire output from the parameters.

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression

# Load the training data
training_df = pd.read_csv('training.csv')

# Define features (X) and target (y)
X_train = training_df[['Temperature', 'Humidity', 'Pressure', 'CO', 'CO2']]
y_train = training_df['Fire']

# Initialize the Logistic Regression model
model = LogisticRegression()

# Train the model
model.fit(X_train, y_train)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %% [markdown]
# # Testing part
# Find out the accuracy in percentage by applying testing.csv to the model.

# %%
import pandas as pd
from sklearn.metrics import accuracy_score

# Load the testing data
testing_df = pd.read_csv('testing.csv')

# Define features (X) and true target (y) for testing
X_test = testing_df[['Temperature', 'Humidity', 'Pressure', 'CO', 'CO2']]
y_test = testing_df['Fire']

# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate the accuracy
accuracy = accuracy_score(y_test, y_pred)
accuracy_percentage = accuracy * 100

print(f"Model accuracy on the testing data: {accuracy_percentage:.2f}%")
# Out:
# Model accuracy on the testing data: 88.92%

# %% [markdown]
# # Cross validation
# Separate the data into training and testing data in a different way than above, then perform training and testing again.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Load the original transformed data
df_fire = pd.read_csv('our_fire_data.csv')

# Define features (X) and target (y)
X = df_fire[['Temperature', 'Humidity', 'Pressure', 'CO', 'CO2']]
y = df_fire['Fire']

# Split data into training and testing sets using a different method (random split)
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

print("Data split into new training and testing sets successfully!")
# Out:
# Data split into new training and testing sets successfully!

# %% [markdown]
# ### Training the model with the new split

# %%
# Initialize a new Logistic Regression model
model_new = LogisticRegression()

# Train the new model
model_new.fit(X_train_new, y_train_new)

print("New model trained successfully!")
# Out:
# New model trained successfully!

# %% [markdown]
# ### Testing the model with the new split

# %%
# Make predictions on the new test set
y_pred_new = model_new.predict(X_test_new)

# Calculate the accuracy
accuracy_new = accuracy_score(y_test_new, y_pred_new)
accuracy_percentage_new = accuracy_new * 100

print(f"New model accuracy on the testing data: {accuracy_percentage_new:.2f}%")
# Out:
# New model accuracy on the testing data: 88.93%

# %% [markdown]
# # Utilizing the model
# Now we have an input:
#
# Temperature = 30.60
# Humidity = 30.20
# Pressure = 1030.30
# CO = 3.10
# CO2 = 512.00
#
# Use the model to make a prediction.

# %%
import pandas as pd

# Define the input values
input_data = {
    'Temperature': [30.60],
    'Humidity': [30.20],
    'Pressure': [1030.30],
    'CO': [3.10],
    'CO2': [512.00]
}

# Create a DataFrame from the input data
input_df = pd.DataFrame(input_data)

# Make a prediction using the trained model (model_new from cross-validation)
prediction = model_new.predict(input_df)

# Output the prediction
if prediction[0]:
    print("Prediction: Fire detected!")
else:
    print("Prediction: No fire detected.")
# Out:
# Prediction: No fire detected.

# %% [markdown]
# # KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

# Load the training and testing data (if not already loaded in the environment)
# Re-loading to ensure availability in case the kernel state resets or for independent execution
df_fire = pd.read_csv('our_fire_data.csv')
X = df_fire[['Temperature', 'Humidity', 'Pressure', 'CO', 'CO2']]
y = df_fire['Fire']

# Split data into training and testing sets using a random split (as done previously for 'new' datasets)
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Initialize the KNN classifier. A common choice for n_neighbors is 5.
knn_model = KNeighborsClassifier(n_neighbors=5)

# Train the KNN model
knn_model.fit(X_train_new, y_train_new)

print("KNN model trained successfully!")

# Make predictions on the test set
y_pred_knn = knn_model.predict(X_test_new)

# Calculate the accuracy
accuracy_knn = accuracy_score(y_test_new, y_pred_knn)
accuracy_percentage_knn = accuracy_knn * 100

print(f"KNN model accuracy on the testing data: {accuracy_percentage_knn:.2f}%")
# Out:
# KNN model trained successfully!
# KNN model accuracy on the testing data: 92.48%

# %% [markdown]
# # Random Forest
# This model would spend more time to compute than Linear Classifier and KNN, but get higher accuracy

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

# Load the training data
training_df = pd.read_csv('training.csv')

# Define features (X) and target (y) for training
X_train = training_df[['Temperature', 'Humidity', 'Pressure', 'CO', 'CO2']]
y_train = training_df['Fire']

# Load the testing data
testing_df = pd.read_csv('testing.csv')

# Define features (X) and true target (y) for testing
X_test = testing_df[['Temperature', 'Humidity', 'Pressure', 'CO', 'CO2']]
y_test = testing_df['Fire']

# Initialize the Random Forest Classifier
# A common choice for n_estimators (number of trees) is 100
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the Random Forest model
rf_model.fit(X_train, y_train)

print("Random Forest model trained successfully!")

# Make predictions on the training set to get training accuracy
y_pred_train_rf = rf_model.predict(X_train)
accuracy_train_rf = accuracy_score(y_train, y_pred_train_rf)
accuracy_percentage_train_rf = accuracy_train_rf * 100
print(f"Random Forest model training accuracy: {accuracy_percentage_train_rf:.2f}%")

# Make predictions on the test set to get testing accuracy
y_pred_test_rf = rf_model.predict(X_test)
accuracy_test_rf = accuracy_score(y_test, y_pred_test_rf)
accuracy_percentage_test_rf = accuracy_test_rf * 100
print(f"Random Forest model testing accuracy: {accuracy_percentage_test_rf:.2f}%")
# Out:
# Random Forest model trained successfully!
# Random Forest model training accuracy: 99.98%
# Random Forest model testing accuracy: 97.96%

# %% [markdown]
# # Supabase Application
# We first save the Random Forest Model as a joblib file. Then we apply this model to the supabase. We will extract these columns: Temperature, Humidity, Pressure, CO, CO2.
# For each line, print out their values inside Supabase and the predicted value (Is fire or not).
#
# Supabase URL: https://yzankkkdstzranyazqgt.supabase.co
#
# Supabase KEY: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Inl6YW5ra2tkc3R6cmFueWF6cWd0Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3Njc5OTAyODcsImV4cCI6MjA4MzU2NjI4N30.V2aPUOi-M3BVslS_nwA85ktDQY4SoDV1tkMXm1QMZV0
#
# Table Name: Wildfire_Sensor_Data

# %%
import joblib

# Save the Random Forest model
joblib.dump(rf_model, 'random_forest_model.joblib')

print("Random Forest model saved as 'random_forest_model.joblib'")
# Out:
# Random Forest model saved as 'random_forest_model.joblib'

# %%
# !pip install supabase
# Out:
# Collecting supabase
#   Downloading supabase-2.28.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting realtime==2.28.0 (from supabase)
#   Downloading realtime-2.28.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting supabase-functions==2.28.0 (from supabase)
#   Downloading supabase_functions-2.28.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting storage3==2.28.0 (from supabase)
#   Downloading storage3-2.28.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting supabase-auth==2.28.0 (from supabase)
#   Downloading supabase_auth-2.28.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting postgrest==2.28.0 (from supabase)
#   Downloading postgrest-2.28.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: httpx<0.29,>=0.26 in /usr/local/lib/python3.12/dist-packages (from supabase) (0.28.1)
# Requirement already satisfied: yarl>=1.22.0 in /usr/local/lib/python3.12/dist-packages (from supabase) (1.22.0)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from postgrest==2.28.0->supabase) (2.1.0)
# Requirement already satisfied: pydantic<3.0,>=1.9 in /usr/local/lib/python3.12/dist-packages (from postgrest==2.28.0->supabase) (2.12.3)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from realtime==2.28.0->supabase) (4.15.0)
# Requirement already satisfied: websockets<16,>=11 in /usr/local/lib/python3.12/dist-packages (from realtime==2.28.0->supabase) (15.0.1)
# Collecting pyiceberg>=0.10.0 (from storage3==2.28.0->supabase)
#   Downloading pyiceberg-0.11.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.28.0->supabase) (2.11.0)
# Collecting strenum>=0.4.15 (from supabase-functions==2.28.0->supabase)
#   Downloading StrEnum-0.4.15-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<0.29,>=0.26->supabase) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<0.29,>=0.26->supabase) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<0.29,>=0.26->supabase) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<0.29,>=0.26->supabase) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.16.0)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.12/dist-packages (from yarl>=1.22.0->supabase) (6.7.1)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from yarl>=1.22.0->supabase) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from deprecation>=2.1.0->postgrest==2.28.0->supabase) (26.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]<0.29,>=0.26->postgrest==2.28.0->supabase) (4.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=1.9->postgrest==2.28.0->supabase) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=1.9->postgrest==2.28.0->supabase) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=1.9->postgrest==2.28.0->supabase) (0.4.2)
# Requirement already satisfied: mmh3<6.0.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (5.2.0)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2.32.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.12/dist-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (8.3.1)
# Requirement already satisfied: rich<15.0.0,>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (13.9.4)
# Collecting strictyaml<2.0.0,>=1.7.0 (from pyiceberg>=0.10.0->storage3==2.28.0->supabase)
#   Downloading strictyaml-1.7.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: fsspec>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2025.3.0)
# Requirement already satisfied: pyparsing<4.0.0,>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (3.3.2)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (9.1.4)
# Collecting pyroaring<2.0.0,>=1.0.0 (from pyiceberg>=0.10.0->storage3==2.28.0->supabase)
#   Downloading pyroaring-1.0.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting cachetools<7.0,>=5.5 (from pyiceberg>=0.10.0->storage3==2.28.0->supabase)
#   Downloading cachetools-6.2.6-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: zstandard<1.0.0,>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (0.25.0)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.28.0->supabase) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.28.0->supabase) (2.0.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.28.0->supabase) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.28.0->supabase) (4.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.20.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.20.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<15.0.0,>=10.11.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<15.0.0,>=10.11.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2.19.2)
# Requirement already satisfied: python-dateutil>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from strictyaml<2.0.0,>=1.7.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2.9.0.post0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.28.0->supabase) (3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=10.11.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.6.0->strictyaml<2.0.0,>=1.7.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (1.17.0)
# Downloading supabase-2.28.0-py3-none-any.whl (16 kB)
# Downloading postgrest-2.28.0-py3-none-any.whl (22 kB)
# Downloading realtime-2.28.0-py3-none-any.whl (22 kB)
# Downloading storage3-2.28.0-py3-none-any.whl (28 kB)
# Downloading supabase_auth-2.28.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 4.0 MB/s eta 0:00:00
# Downloading supabase_functions-2.28.0-py3-none-any.whl (8.8 kB)
# Downloading pyiceberg-0.11.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (729 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 730.0/730.0 kB 9.1 MB/s eta 0:00:00
# Downloading StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Downloading cachetools-6.2.6-py3-none-any.whl (11 kB)
# Downloading pyroaring-1.0.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.9 MB/s eta 0:00:00
# Downloading strictyaml-1.7.3-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.9/123.9 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: strenum, pyroaring, cachetools, strictyaml, realtime, pyiceberg, supabase-functions, supabase-auth, storage3, postgrest, supabase
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 7.0.1
#     Uninstalling cachetools-7.0.1:
#       Successfully uninstalled cachetools-7.0.1
# Successfully installed cachetools-6.2.6 postgrest-2.28.0 pyiceberg-0.11.0 pyroaring-1.0.3 realtime-2.28.0 storage3-2.28.0 strenum-0.4.15 strictyaml-1.7.3 supabase-2.28.0 supabase-auth-2.28.0 supabase-functions-2.28.0

# %%
import pandas as pd
import joblib
from supabase import create_client, Client

# Supabase URL and Key
SUPABASE_URL = "https://yzankkkdstzranyazqgt.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Inl6YW5ra2tkc3R6cmFueWF6cWd0Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3Njc5OTAyODcsImV4cCI6MjA4MzU2NjI4N30.V2aPUOi-M3BVslS_nwA85ktDQY4SoDV1tkMXm1QMZV0"
TABLE_NAME = "Wildfire_Sensor_Data"

# Initialize Supabase client
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

# Load the trained Random Forest model
loaded_rf_model = joblib.load('random_forest_model.joblib')

print("Supabase client initialized and model loaded.")
# Out:
# Supabase client initialized and model loaded.

# %%
# Fetch data from Supabase
def fetch_data_from_supabase(table_name):
    try:
        # Select the relevant columns
        response = supabase.from_(table_name).select('Temperature, Humidity, Pressure, CO, CO2').execute()
        data = response.data
        if not data:
            print(f"No data found in table: {table_name}")
            return pd.DataFrame()
        return pd.DataFrame(data)
    except Exception as e:
        print(f"Error fetching data from Supabase: {e}")
        return pd.DataFrame()

# Get data from Supabase
supabase_df = fetch_data_from_supabase(TABLE_NAME)

if not supabase_df.empty:
    print(f"Fetched {len(supabase_df)} rows from Supabase.")
    # Make predictions for each row
    for index, row in supabase_df.iterrows():
        input_data = pd.DataFrame([row[['Temperature', 'Humidity', 'Pressure', 'CO', 'CO2']]])
        prediction = loaded_rf_model.predict(input_data)

        # Output the prediction
        prediction_text = "Fire detected!" if prediction[0] else "No fire detected."
        print(f"Data: Temperature={row['Temperature']:.2f}, Humidity={row['Humidity']:.2f}, Pressure={row['Pressure']:.2f}, CO={row['CO']:.2f}, CO2={row['CO2']:.2f} -> Prediction: {prediction_text}")
else:
    print("No data to process from Supabase.")
# Out:
# Fetched 528 rows from Supabase.
# Data: Temperature=nan, Humidity=nan, Pressure=nan, CO=nan, CO2=nan -> Prediction: No fire detected.
# Data: Temperature=26.66, Humidity=37.39, Pressure=1015.78, CO=1.00, CO2=278.00 -> Prediction: No fire detected.
# Data: Temperature=26.74, Humidity=37.28, Pressure=1015.75, CO=0.00, CO2=278.00 -> Prediction: No fire detected.
# Data: Temperature=26.90, Humidity=37.12, Pressure=1015.83, CO=0.00, CO2=277.00 -> Prediction: No fire detected.
# Data: Temperature=26.99, Humidity=36.98, Pressure=1015.73, CO=0.00, CO2=277.00 -> Prediction: No fire detected.
# Data: Temperature=21.83, Humidity=40.98, Pressure=1015.95, CO=0.00, CO2=328.00 -> Prediction: No fire detected.
# Data: Temperature=21.64, Humidity=42.39, Pressure=1015.95, CO=0.00, CO2=338.00 -> Prediction: No fire detected.
# Data: Temperature=21.60, Humidity=42.43, Pressure=1015.85, CO=0.00, CO2=337.00 -> Prediction: No fire detected.
# Data: Temperature=21.62, Humidity=42.48, Pressure=1015.96, CO=0.00, CO2=336.00 -> Prediction: No fire detected.
# Data: Temperature=21.61, Humidity=42.52, Pressure=1015.97, CO=0.00, CO2=335.00 -> Prediction: No fire detected.
# Data: Temperature=21.61, Humidity=42.53, Pressure=1015.97, CO=0.00, CO2=332.00 -> Prediction: No fire detected.
# Data: Temperature=21.61, Humidity=42.56, Pressure=1015.97, CO=0.00, CO2=331.00 -> Prediction: No fire detected.
# Data: Temperature=21.58, Humidity=42.54, Pressure=1015.95, CO=0.00, CO2=328.00 -> Prediction: No fire detected.
# Data: Temperature=21.58, Humidity=42.52, Pressure=1015.99, CO=0.00, CO2=327.00 -> Prediction: No fire detected.
# Data: Temperature=21.60, Humidity=42.52, Pressure=1015.96, CO=0.00, CO2=327.00 -> Prediction: No fire detected.
# Data: Temperature=21.64, Humidity=42.52, Pressure=1015.94, CO=0.00, CO2=326.00 -> Prediction: No fire detected.
# Data: Temperature=21.72, Humidity=42.50, Pressure=1015.93, CO=0.00, CO2=325.00 -> Prediction: No fire detected.
# Data: Temperature=21.78, Humidity=42.49, Pressure=1015.92, CO=0.00, CO2=325.00 -> Prediction: No fire detected.
# Data: Temperature=21.84, Humidity=42.44, Pressure=1015.91, CO=0.00, CO2=325.00 -> Prediction: No fire detected.
# Data: Temperature=21.94, Humidity=42.40, Pressure=1015.95, CO=0.00, CO2=326.00 -> Prediction: No fire detected.
# Data: Temperature=22.04, Humidity=42.33, Pressure=1015.98, CO=0.00, CO2=326.00 -> Prediction: No fire detected.
# Data: Temperature=22.08, Humidity=42.27, Pressure=1015.99, CO=0.00, CO2=327.00 -> Prediction: No fire detected.
# Data: Temperature=22.10, Humidity=42.25, Pressure=1015.88, CO=0.00, CO2=328.00 -> Prediction: No fire detected.
# Data: Temperature=22.15, Humidity=42.22, Pressure=1016.01, CO=0.00, CO2=329.00 -> Prediction: No fire detected.
# Data: Temperature=22.21, Humidity=42.22, Pressure=1016.03, CO=0.00, CO2=331.00 -> Prediction: No fire detected.
# Data: Temperature=22.28, Humidity=42.10, Pressure=1015.95, CO=0.00, CO2=333.00 -> Prediction: No fire detected.
# Data: Temperature=22.37, Humidity=41.97, Pressure=1015.96, CO=0.00, CO2=335.00 -> Prediction: No fire detected.
# Data: Temperature=22.45, Humidity=41.91, Pressure=1015.96, CO=0.00, CO2=338.00 -> Prediction: No fire detected.
# Data: Temperature=22.57, Humidity=41.86, Pressure=1015.93, CO=0.00, CO2=343.00 -> Prediction: No fire detected.
# Data: Temperature=22.67, Humidity=41.72, Pressure=1015.97, CO=0.00, CO2=345.00 -> Prediction: No fire detected.
# Data: Temperature=27.13, Humidity=36.79, Pressure=1015.74, CO=0.00, CO2=278.00 -> Prediction: No fire detected.
# Data: Temperature=27.19, Humidity=36.69, Pressure=1015.81, CO=0.00, CO2=278.00 -> Prediction: No fire detected.
# Data: Temperature=27.30, Humidity=36.55, Pressure=1015.75, CO=0.00, CO2=276.00 -> Prediction: No fire detected.
# Data: Temperature=27.38, Humidity=36.44, Pressure=1015.77, CO=0.00, CO2=275.00 -> Prediction: No fire detected.
# Data: Temperature=22.70, Humidity=41.60, Pressure=1015.96, CO=0.00, CO2=348.00 -> Prediction: No fire detected.
# Data: Temperature=22.74, Humidity=41.55, Pressure=1015.97, CO=0.00, CO2=351.00 -> Prediction: No fire detected.
# Data: Temperature=22.87, Humidity=41.56, Pressure=1015.96, CO=0.00, CO2=356.00 -> Prediction: No fire detected.
# Data: Temperature=27.54, Humidity=36.28, Pressure=1015.80, CO=0.00, CO2=274.00 -> Prediction: No fire detected.
# Data: Temperature=22.92, Humidity=41.51, Pressure=1016.01, CO=0.00, CO2=358.00 -> Prediction: No fire detected.
# Data: Temperature=22.94, Humidity=41.44, Pressure=1015.97, CO=0.00, CO2=359.00 -> Prediction: No fire detected.
# Data: Temperature=23.00, Humidity=41.37, Pressure=1015.90, CO=0.00, CO2=361.00 -> Prediction: No fire detected.
# Data: Temperature=27.55, Humidity=36.15, Pressure=1015.75, CO=0.00, CO2=273.00 -> Prediction: No fire detected.
# Data: Temperature=27.66, Humidity=36.06, Pressure=1015.75, CO=0.00, CO2=272.00 -> Prediction: No fire detected.
# Data: Temperature=27.74, Humidity=35.99, Pressure=1015.77, CO=0.00, CO2=271.00 -> Prediction: No fire detected.
# Data: Temperature=27.84, Humidity=35.94, Pressure=1015.79, CO=0.00, CO2=270.00 -> Prediction: No fire detected.
# Data: Temperature=27.86, Humidity=35.82, Pressure=1015.71, CO=0.00, CO2=270.00 -> Prediction: No fire detected.
# Data: Temperature=28.01, Humidity=35.78, Pressure=1015.72, CO=0.00, CO2=274.00 -> Prediction: No fire detected.
# Data: Temperature=28.23, Humidity=35.67, Pressure=1015.76, CO=1.00, CO2=277.00 -> Prediction: Fire detected!
# Data: Temperature=21.88, Humidity=41.01, Pressure=1016.05, CO=0.00, CO2=328.00 -> Prediction: No fire detected.
# Data: Temperature=23.06, Humidity=41.28, Pressure=1015.96, CO=0.00, CO2=362.00 -> Prediction: No fire detected.
# Data: Temperature=23.08, Humidity=41.05, Pressure=1015.94, CO=0.00, CO2=362.00 -> Prediction: No fire detected.
# Data: Temperature=23.10, Humidity=40.94, Pressure=1015.94, CO=0.00, CO2=363.00 -> Prediction: No fire detected.
# Data: Temperature=23.12, Humidity=40.88, Pressure=1015.92, CO=0.00, CO2=363.00 -> Prediction: No fire detected.
# Data: Temperature=23.12, Humidity=40.84, Pressure=1015.95, CO=0.00, CO2=363.00 -> Prediction: No fire detected.
# Data: Temperature=23.13, Humidity=40.81, Pressure=1015.91, CO=0.00, CO2=364.00 -> Prediction: No fire detected.
# Data: Temperature=23.15, Humidity=40.74, Pressure=1015.95, CO=0.00, CO2=365.00 -> Prediction: No fire detected.
# Data: Temperature=23.21, Humidity=40.72, Pressure=1015.90, CO=0.00, CO2=365.00 -> Prediction: No fire detected.
# Data: Temperature=23.26, Humidity=40.73, Pressure=1015.93, CO=0.00, CO2=366.00 -> Prediction: No fire detected.
# Data: Temperature=23.24, Humidity=40.77, Pressure=1015.90, CO=0.00, CO2=368.00 -> Prediction: No fire detected.
# Data: Temperature=21.86, Humidity=40.97, Pressure=1015.95, CO=0.00, CO2=328.00 -> Prediction: No fire detected.
# Data: Temperature=23.23, Humidity=40.74, Pressure=1015.99, CO=0.00, CO2=369.00 -> Prediction: No fire detected.
# Data: Temperature=23.28, Humidity=40.78, Pressure=1015.93, CO=0.00, CO2=370.00 -> Prediction: No fire detected.
# Data: Temperature=23.26, Humidity=40.74, Pressure=1015.95, CO=0.00, CO2=369.00 -> Prediction: No fire detected.
# Data: Temperature=23.20, Humidity=40.66, Pressure=1015.94, CO=0.00, CO2=370.00 -> Prediction: No fire detected.
# Data: Temperature=23.16, Humidity=40.54, Pressure=1015.88, CO=0.00, CO2=374.00 -> Prediction: No fire detected.
# Data: Temperature=23.14, Humidity=40.38, Pressure=1016.01, CO=0.00, CO2=387.00 -> Prediction: No fire detected.
# Data: Temperature=23.09, Humidity=40.31, Pressure=1015.91, CO=0.00, CO2=396.00 -> Prediction: No fire detected.
# Data: Temperature=23.07, Humidity=40.28, Pressure=1015.97, CO=0.00, CO2=402.00 -> Prediction: No fire detected.
# Data: Temperature=23.03, Humidity=40.27, Pressure=1015.93, CO=0.00, CO2=405.00 -> Prediction: No fire detected.
# Data: Temperature=22.95, Humidity=40.30, Pressure=1015.96, CO=0.00, CO2=403.00 -> Prediction: No fire detected.
# Data: Temperature=22.91, Humidity=40.35, Pressure=1016.05, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=22.14, Humidity=40.54, Pressure=1015.90, CO=0.00, CO2=366.00 -> Prediction: No fire detected.
# Data: Temperature=22.11, Humidity=40.53, Pressure=1015.92, CO=0.00, CO2=364.00 -> Prediction: No fire detected.
# Data: Temperature=22.08, Humidity=40.53, Pressure=1015.91, CO=0.00, CO2=363.00 -> Prediction: No fire detected.
# Data: Temperature=22.06, Humidity=40.53, Pressure=1015.93, CO=0.00, CO2=361.00 -> Prediction: No fire detected.
# Data: Temperature=22.04, Humidity=40.60, Pressure=1015.95, CO=0.00, CO2=359.00 -> Prediction: No fire detected.
# Data: Temperature=22.04, Humidity=40.64, Pressure=1015.95, CO=0.00, CO2=357.00 -> Prediction: No fire detected.
# Data: Temperature=22.03, Humidity=40.67, Pressure=1015.91, CO=0.00, CO2=354.00 -> Prediction: No fire detected.
# Data: Temperature=22.03, Humidity=40.73, Pressure=1016.00, CO=0.00, CO2=352.00 -> Prediction: No fire detected.
# Data: Temperature=22.02, Humidity=40.80, Pressure=1015.87, CO=0.00, CO2=351.00 -> Prediction: No fire detected.
# Data: Temperature=22.01, Humidity=40.83, Pressure=1015.91, CO=0.00, CO2=352.00 -> Prediction: No fire detected.
# Data: Temperature=21.98, Humidity=40.81, Pressure=1015.93, CO=0.00, CO2=350.00 -> Prediction: No fire detected.
# Data: Temperature=21.96, Humidity=40.87, Pressure=1015.93, CO=0.00, CO2=348.00 -> Prediction: No fire detected.
# Data: Temperature=21.97, Humidity=40.93, Pressure=1015.93, CO=0.00, CO2=346.00 -> Prediction: No fire detected.
# Data: Temperature=21.93, Humidity=40.96, Pressure=1015.93, CO=0.00, CO2=344.00 -> Prediction: No fire detected.
# Data: Temperature=21.93, Humidity=40.98, Pressure=1015.96, CO=0.00, CO2=342.00 -> Prediction: No fire detected.
# Data: Temperature=21.94, Humidity=41.02, Pressure=1015.99, CO=0.00, CO2=340.00 -> Prediction: No fire detected.
# Data: Temperature=21.93, Humidity=41.07, Pressure=1015.93, CO=0.00, CO2=338.00 -> Prediction: No fire detected.
# Data: Temperature=21.91, Humidity=41.10, Pressure=1015.86, CO=0.00, CO2=337.00 -> Prediction: No fire detected.
# Data: Temperature=21.92, Humidity=41.11, Pressure=1015.98, CO=0.00, CO2=335.00 -> Prediction: No fire detected.
# Data: Temperature=21.93, Humidity=41.11, Pressure=1016.00, CO=0.00, CO2=334.00 -> Prediction: No fire detected.
# Data: Temperature=21.88, Humidity=41.15, Pressure=1015.98, CO=0.00, CO2=332.00 -> Prediction: No fire detected.
# Data: Temperature=21.88, Humidity=41.20, Pressure=1015.97, CO=0.00, CO2=332.00 -> Prediction: No fire detected.
# Data: Temperature=21.88, Humidity=41.25, Pressure=1015.92, CO=0.00, CO2=332.00 -> Prediction: No fire detected.
# Data: Temperature=21.85, Humidity=41.23, Pressure=1015.90, CO=0.00, CO2=332.00 -> Prediction: No fire detected.
# Data: Temperature=21.85, Humidity=41.20, Pressure=1015.93, CO=0.00, CO2=333.00 -> Prediction: No fire detected.
# Data: Temperature=21.85, Humidity=41.24, Pressure=1015.98, CO=0.00, CO2=336.00 -> Prediction: No fire detected.
# Data: Temperature=21.80, Humidity=41.30, Pressure=1015.87, CO=0.00, CO2=337.00 -> Prediction: No fire detected.
# Data: Temperature=21.79, Humidity=41.39, Pressure=1015.97, CO=0.00, CO2=338.00 -> Prediction: No fire detected.
# Data: Temperature=21.76, Humidity=41.46, Pressure=1015.95, CO=0.00, CO2=338.00 -> Prediction: No fire detected.
# Data: Temperature=21.77, Humidity=41.64, Pressure=1015.95, CO=0.00, CO2=336.00 -> Prediction: No fire detected.
# Data: Temperature=21.75, Humidity=41.65, Pressure=1015.96, CO=0.00, CO2=336.00 -> Prediction: No fire detected.
# Data: Temperature=21.76, Humidity=41.68, Pressure=1015.94, CO=0.00, CO2=334.00 -> Prediction: No fire detected.
# Data: Temperature=28.31, Humidity=35.57, Pressure=1015.81, CO=0.00, CO2=279.00 -> Prediction: Fire detected!
# Data: Temperature=28.43, Humidity=35.01, Pressure=1015.73, CO=0.00, CO2=277.00 -> Prediction: Fire detected!
# Data: Temperature=28.58, Humidity=34.95, Pressure=1015.77, CO=0.00, CO2=277.00 -> Prediction: No fire detected.
# Data: Temperature=28.71, Humidity=34.57, Pressure=1015.74, CO=0.00, CO2=276.00 -> Prediction: No fire detected.
# Data: Temperature=28.87, Humidity=34.47, Pressure=1015.80, CO=0.00, CO2=275.00 -> Prediction: No fire detected.
# Data: Temperature=29.05, Humidity=34.08, Pressure=1015.78, CO=0.00, CO2=271.00 -> Prediction: No fire detected.
# Data: Temperature=29.12, Humidity=33.88, Pressure=1015.74, CO=0.00, CO2=268.00 -> Prediction: No fire detected.
# Data: Temperature=29.20, Humidity=33.57, Pressure=1015.78, CO=0.00, CO2=266.00 -> Prediction: No fire detected.
# Data: Temperature=29.28, Humidity=33.50, Pressure=1015.81, CO=1.00, CO2=264.00 -> Prediction: Fire detected!
# Data: Temperature=29.37, Humidity=33.43, Pressure=1015.77, CO=0.00, CO2=262.00 -> Prediction: No fire detected.
# Data: Temperature=29.39, Humidity=33.32, Pressure=1015.82, CO=0.00, CO2=260.00 -> Prediction: No fire detected.
# Data: Temperature=29.48, Humidity=33.24, Pressure=1015.70, CO=0.00, CO2=259.00 -> Prediction: Fire detected!
# Data: Temperature=29.59, Humidity=32.93, Pressure=1015.74, CO=0.00, CO2=253.00 -> Prediction: Fire detected!
# Data: Temperature=29.65, Humidity=32.85, Pressure=1015.72, CO=0.00, CO2=251.00 -> Prediction: Fire detected!
# Data: Temperature=29.62, Humidity=32.75, Pressure=1015.73, CO=0.00, CO2=249.00 -> Prediction: Fire detected!
# Data: Temperature=29.48, Humidity=32.71, Pressure=1015.75, CO=0.00, CO2=248.00 -> Prediction: Fire detected!
# Data: Temperature=29.39, Humidity=32.71, Pressure=1015.75, CO=0.00, CO2=248.00 -> Prediction: No fire detected.
# Data: Temperature=29.32, Humidity=32.74, Pressure=1015.81, CO=0.00, CO2=248.00 -> Prediction: No fire detected.
# Data: Temperature=29.35, Humidity=32.78, Pressure=1015.78, CO=0.00, CO2=247.00 -> Prediction: No fire detected.
# Data: Temperature=29.41, Humidity=32.81, Pressure=1015.73, CO=0.00, CO2=246.00 -> Prediction: No fire detected.
# Data: Temperature=29.53, Humidity=32.85, Pressure=1015.69, CO=19.00, CO2=253.00 -> Prediction: No fire detected.
# Data: Temperature=29.51, Humidity=32.85, Pressure=1015.75, CO=21.00, CO2=258.00 -> Prediction: No fire detected.
# Data: Temperature=29.75, Humidity=32.75, Pressure=1015.69, CO=16.00, CO2=260.00 -> Prediction: No fire detected.
# Data: Temperature=29.77, Humidity=32.68, Pressure=1015.72, CO=32.00, CO2=260.00 -> Prediction: No fire detected.
# Data: Temperature=29.87, Humidity=32.58, Pressure=1015.69, CO=19.00, CO2=261.00 -> Prediction: No fire detected.
# Data: Temperature=29.96, Humidity=32.47, Pressure=1015.74, CO=10.00, CO2=261.00 -> Prediction: No fire detected.
# Data: Temperature=30.11, Humidity=32.31, Pressure=1015.71, CO=6.00, CO2=261.00 -> Prediction: No fire detected.
# Data: Temperature=30.19, Humidity=32.18, Pressure=1015.78, CO=4.00, CO2=262.00 -> Prediction: No fire detected.
# Data: Temperature=30.27, Humidity=31.98, Pressure=1015.68, CO=3.00, CO2=264.00 -> Prediction: Fire detected!
# Data: Temperature=30.35, Humidity=31.78, Pressure=1015.75, CO=3.00, CO2=265.00 -> Prediction: Fire detected!
# Data: Temperature=30.46, Humidity=31.38, Pressure=1015.73, CO=2.00, CO2=264.00 -> Prediction: Fire detected!
# Data: Temperature=30.44, Humidity=31.19, Pressure=1015.70, CO=1.00, CO2=264.00 -> Prediction: Fire detected!
# Data: Temperature=30.57, Humidity=31.00, Pressure=1015.72, CO=1.00, CO2=262.00 -> Prediction: Fire detected!
# Data: Temperature=30.49, Humidity=30.89, Pressure=1015.75, CO=2.00, CO2=261.00 -> Prediction: Fire detected!
# Data: Temperature=30.44, Humidity=30.93, Pressure=1015.75, CO=2.00, CO2=260.00 -> Prediction: Fire detected!
# Data: Temperature=31.18, Humidity=30.42, Pressure=1015.71, CO=0.00, CO2=299.00 -> Prediction: No fire detected.
# Data: Temperature=31.17, Humidity=30.36, Pressure=1015.66, CO=0.00, CO2=301.00 -> Prediction: No fire detected.
# Data: Temperature=31.10, Humidity=30.39, Pressure=1015.71, CO=0.00, CO2=304.00 -> Prediction: No fire detected.
# Data: Temperature=31.04, Humidity=30.48, Pressure=1015.68, CO=0.00, CO2=305.00 -> Prediction: No fire detected.
# Data: Temperature=30.99, Humidity=30.63, Pressure=1015.71, CO=25.00, CO2=306.00 -> Prediction: No fire detected.
# Data: Temperature=30.97, Humidity=30.71, Pressure=1015.65, CO=110.00, CO2=308.00 -> Prediction: No fire detected.
# Data: Temperature=30.97, Humidity=30.84, Pressure=1015.66, CO=56.00, CO2=311.00 -> Prediction: No fire detected.
# Data: Temperature=31.06, Humidity=30.96, Pressure=1015.71, CO=8.00, CO2=316.00 -> Prediction: No fire detected.
# Data: Temperature=31.13, Humidity=30.96, Pressure=1015.69, CO=6.00, CO2=317.00 -> Prediction: No fire detected.
# Data: Temperature=31.22, Humidity=30.94, Pressure=1015.77, CO=6.00, CO2=318.00 -> Prediction: No fire detected.
# Data: Temperature=31.27, Humidity=30.89, Pressure=1015.71, CO=32.00, CO2=319.00 -> Prediction: No fire detected.
# Data: Temperature=31.28, Humidity=30.88, Pressure=1015.67, CO=27.00, CO2=321.00 -> Prediction: No fire detected.
# Data: Temperature=31.27, Humidity=30.81, Pressure=1015.71, CO=9.00, CO2=322.00 -> Prediction: No fire detected.
# Data: Temperature=31.22, Humidity=30.84, Pressure=1015.66, CO=7.00, CO2=323.00 -> Prediction: No fire detected.
# Data: Temperature=31.19, Humidity=30.81, Pressure=1015.71, CO=5.00, CO2=323.00 -> Prediction: No fire detected.
# Data: Temperature=31.16, Humidity=30.83, Pressure=1015.67, CO=4.00, CO2=322.00 -> Prediction: No fire detected.
# Data: Temperature=31.15, Humidity=30.88, Pressure=1015.69, CO=4.00, CO2=321.00 -> Prediction: No fire detected.
# Data: Temperature=31.18, Humidity=30.93, Pressure=1015.73, CO=4.00, CO2=320.00 -> Prediction: No fire detected.
# Data: Temperature=31.19, Humidity=31.00, Pressure=1015.72, CO=4.00, CO2=319.00 -> Prediction: No fire detected.
# Data: Temperature=31.21, Humidity=31.10, Pressure=1015.73, CO=3.00, CO2=320.00 -> Prediction: No fire detected.
# Data: Temperature=31.18, Humidity=31.16, Pressure=1015.64, CO=4.00, CO2=320.00 -> Prediction: No fire detected.
# Data: Temperature=31.28, Humidity=31.13, Pressure=1015.55, CO=0.00, CO2=318.00 -> Prediction: No fire detected.
# Data: Temperature=34.54, Humidity=28.30, Pressure=1015.58, CO=18.00, CO2=324.00 -> Prediction: No fire detected.
# Data: Temperature=34.13, Humidity=28.37, Pressure=1015.63, CO=0.00, CO2=340.00 -> Prediction: No fire detected.
# Data: Temperature=33.83, Humidity=28.45, Pressure=1015.69, CO=0.00, CO2=336.00 -> Prediction: No fire detected.
# Data: Temperature=33.75, Humidity=28.77, Pressure=1015.76, CO=0.00, CO2=331.00 -> Prediction: No fire detected.
# Data: Temperature=33.61, Humidity=29.31, Pressure=1015.70, CO=0.00, CO2=326.00 -> Prediction: No fire detected.
# Data: Temperature=33.55, Humidity=29.44, Pressure=1015.70, CO=0.00, CO2=322.00 -> Prediction: No fire detected.
# Data: Temperature=33.28, Humidity=29.71, Pressure=1015.73, CO=0.00, CO2=311.00 -> Prediction: No fire detected.
# Data: Temperature=32.64, Humidity=29.61, Pressure=1015.73, CO=2.00, CO2=374.00 -> Prediction: No fire detected.
# Data: Temperature=23.30, Humidity=42.49, Pressure=1015.80, CO=0.00, CO2=332.00 -> Prediction: No fire detected.
# Data: Temperature=23.31, Humidity=42.42, Pressure=1015.71, CO=0.00, CO2=332.00 -> Prediction: No fire detected.
# Data: Temperature=23.30, Humidity=42.58, Pressure=1015.67, CO=0.00, CO2=332.00 -> Prediction: No fire detected.
# Data: Temperature=23.31, Humidity=42.21, Pressure=1015.70, CO=0.00, CO2=330.00 -> Prediction: No fire detected.
# Data: Temperature=23.32, Humidity=42.10, Pressure=1015.75, CO=0.00, CO2=330.00 -> Prediction: No fire detected.
# Data: Temperature=23.36, Humidity=42.05, Pressure=1015.82, CO=0.00, CO2=330.00 -> Prediction: No fire detected.
# Data: Temperature=23.40, Humidity=42.01, Pressure=1015.74, CO=0.00, CO2=331.00 -> Prediction: No fire detected.
# Data: Temperature=23.43, Humidity=41.99, Pressure=1015.78, CO=0.00, CO2=335.00 -> Prediction: No fire detected.
# Data: Temperature=23.52, Humidity=42.42, Pressure=1015.79, CO=0.00, CO2=342.00 -> Prediction: No fire detected.
# Data: Temperature=23.54, Humidity=42.25, Pressure=1015.82, CO=0.00, CO2=342.00 -> Prediction: No fire detected.
# Data: Temperature=23.53, Humidity=42.09, Pressure=1015.75, CO=0.00, CO2=342.00 -> Prediction: No fire detected.
# Data: Temperature=23.51, Humidity=41.94, Pressure=1015.84, CO=0.00, CO2=341.00 -> Prediction: No fire detected.
# Data: Temperature=23.45, Humidity=41.41, Pressure=1015.79, CO=0.00, CO2=329.00 -> Prediction: No fire detected.
# Data: Temperature=23.42, Humidity=41.41, Pressure=1015.74, CO=0.00, CO2=329.00 -> Prediction: No fire detected.
# Data: Temperature=23.45, Humidity=41.42, Pressure=1015.73, CO=0.00, CO2=329.00 -> Prediction: No fire detected.
# Data: Temperature=23.48, Humidity=41.38, Pressure=1015.68, CO=0.00, CO2=329.00 -> Prediction: No fire detected.
# Data: Temperature=23.49, Humidity=41.35, Pressure=1015.80, CO=0.00, CO2=330.00 -> Prediction: No fire detected.
# Data: Temperature=23.51, Humidity=41.27, Pressure=1015.81, CO=0.00, CO2=332.00 -> Prediction: No fire detected.
# Data: Temperature=23.54, Humidity=41.15, Pressure=1015.82, CO=0.00, CO2=333.00 -> Prediction: No fire detected.
# Data: Temperature=23.55, Humidity=41.09, Pressure=1015.78, CO=0.00, CO2=334.00 -> Prediction: No fire detected.
# Data: Temperature=23.56, Humidity=41.05, Pressure=1015.72, CO=0.00, CO2=333.00 -> Prediction: No fire detected.
# Data: Temperature=23.57, Humidity=40.97, Pressure=1015.82, CO=0.00, CO2=333.00 -> Prediction: No fire detected.
# Data: Temperature=23.56, Humidity=40.90, Pressure=1015.81, CO=0.00, CO2=332.00 -> Prediction: No fire detected.
# Data: Temperature=23.56, Humidity=40.82, Pressure=1015.78, CO=0.00, CO2=332.00 -> Prediction: No fire detected.
# Data: Temperature=23.57, Humidity=40.78, Pressure=1015.74, CO=0.00, CO2=332.00 -> Prediction: No fire detected.
# Data: Temperature=23.55, Humidity=40.72, Pressure=1015.78, CO=0.00, CO2=332.00 -> Prediction: No fire detected.
# Data: Temperature=23.56, Humidity=40.69, Pressure=1015.77, CO=0.00, CO2=331.00 -> Prediction: No fire detected.
# Data: Temperature=23.58, Humidity=40.68, Pressure=1015.81, CO=0.00, CO2=331.00 -> Prediction: No fire detected.
# Data: Temperature=23.59, Humidity=40.59, Pressure=1015.75, CO=0.00, CO2=331.00 -> Prediction: No fire detected.
# Data: Temperature=23.59, Humidity=40.49, Pressure=1015.75, CO=0.00, CO2=330.00 -> Prediction: No fire detected.
# Data: Temperature=23.59, Humidity=40.34, Pressure=1015.74, CO=0.00, CO2=329.00 -> Prediction: No fire detected.
# Data: Temperature=23.60, Humidity=40.21, Pressure=1015.76, CO=0.00, CO2=329.00 -> Prediction: No fire detected.
# Data: Temperature=23.56, Humidity=40.07, Pressure=1015.77, CO=0.00, CO2=328.00 -> Prediction: No fire detected.
# Data: Temperature=23.57, Humidity=40.00, Pressure=1015.72, CO=0.00, CO2=327.00 -> Prediction: No fire detected.
# Data: Temperature=23.61, Humidity=39.92, Pressure=1015.69, CO=0.00, CO2=326.00 -> Prediction: No fire detected.
# Data: Temperature=23.63, Humidity=39.85, Pressure=1015.81, CO=0.00, CO2=326.00 -> Prediction: No fire detected.
# Data: Temperature=23.64, Humidity=39.76, Pressure=1015.79, CO=0.00, CO2=325.00 -> Prediction: No fire detected.
# Data: Temperature=25.64, Humidity=39.12, Pressure=1015.66, CO=0.00, CO2=292.00 -> Prediction: No fire detected.
# Data: Temperature=25.63, Humidity=39.10, Pressure=1015.73, CO=0.00, CO2=290.00 -> Prediction: No fire detected.
# Data: Temperature=25.79, Humidity=39.00, Pressure=1015.73, CO=0.00, CO2=287.00 -> Prediction: No fire detected.
# Data: Temperature=25.81, Humidity=38.79, Pressure=1015.70, CO=0.00, CO2=286.00 -> Prediction: No fire detected.
# Data: Temperature=25.87, Humidity=38.60, Pressure=1015.72, CO=0.00, CO2=285.00 -> Prediction: No fire detected.
# Data: Temperature=25.95, Humidity=38.48, Pressure=1015.67, CO=0.00, CO2=284.00 -> Prediction: No fire detected.
# Data: Temperature=26.01, Humidity=38.24, Pressure=1015.75, CO=0.00, CO2=283.00 -> Prediction: No fire detected.
# Data: Temperature=26.17, Humidity=38.26, Pressure=1015.75, CO=0.00, CO2=281.00 -> Prediction: No fire detected.
# Data: Temperature=26.22, Humidity=38.18, Pressure=1015.76, CO=0.00, CO2=280.00 -> Prediction: No fire detected.
# Data: Temperature=26.32, Humidity=38.11, Pressure=1015.75, CO=0.00, CO2=279.00 -> Prediction: No fire detected.
# Data: Temperature=26.39, Humidity=38.02, Pressure=1015.74, CO=0.00, CO2=279.00 -> Prediction: No fire detected.
# Data: Temperature=26.41, Humidity=37.91, Pressure=1015.70, CO=0.00, CO2=278.00 -> Prediction: No fire detected.
# Data: Temperature=26.42, Humidity=37.79, Pressure=1015.77, CO=0.00, CO2=278.00 -> Prediction: No fire detected.
# Data: Temperature=26.44, Humidity=37.62, Pressure=1015.78, CO=0.00, CO2=278.00 -> Prediction: No fire detected.
# Data: Temperature=26.44, Humidity=37.56, Pressure=1015.71, CO=0.00, CO2=279.00 -> Prediction: No fire detected.
# Data: Temperature=26.50, Humidity=37.43, Pressure=1015.70, CO=0.00, CO2=278.00 -> Prediction: No fire detected.
# Data: Temperature=26.53, Humidity=37.43, Pressure=1015.74, CO=0.00, CO2=279.00 -> Prediction: No fire detected.
# Data: Temperature=30.33, Humidity=30.95, Pressure=1015.75, CO=1.00, CO2=257.00 -> Prediction: Fire detected!
# Data: Temperature=30.28, Humidity=30.90, Pressure=1015.75, CO=2.00, CO2=256.00 -> Prediction: Fire detected!
# Data: Temperature=30.34, Humidity=30.84, Pressure=1015.74, CO=19.00, CO2=253.00 -> Prediction: No fire detected.
# Data: Temperature=30.36, Humidity=30.83, Pressure=1015.72, CO=21.00, CO2=252.00 -> Prediction: No fire detected.
# Data: Temperature=30.44, Humidity=30.68, Pressure=1015.70, CO=6.00, CO2=251.00 -> Prediction: No fire detected.
# Data: Temperature=30.41, Humidity=30.69, Pressure=1015.74, CO=4.00, CO2=250.00 -> Prediction: No fire detected.
# Data: Temperature=30.45, Humidity=30.72, Pressure=1015.72, CO=4.00, CO2=251.00 -> Prediction: No fire detected.
# Data: Temperature=30.58, Humidity=30.73, Pressure=1015.65, CO=3.00, CO2=254.00 -> Prediction: Fire detected!
# Data: Temperature=30.60, Humidity=30.71, Pressure=1015.68, CO=3.00, CO2=255.00 -> Prediction: Fire detected!
# Data: Temperature=30.60, Humidity=30.69, Pressure=1015.73, CO=3.00, CO2=258.00 -> Prediction: Fire detected!
# Data: Temperature=30.71, Humidity=30.77, Pressure=1015.74, CO=3.00, CO2=263.00 -> Prediction: Fire detected!
# Data: Temperature=30.77, Humidity=30.77, Pressure=1015.76, CO=3.00, CO2=265.00 -> Prediction: No fire detected.
# Data: Temperature=30.82, Humidity=30.82, Pressure=1015.66, CO=3.00, CO2=268.00 -> Prediction: No fire detected.
# Data: Temperature=30.90, Humidity=30.79, Pressure=1015.70, CO=1.00, CO2=271.00 -> Prediction: No fire detected.
# Data: Temperature=30.91, Humidity=30.76, Pressure=1015.73, CO=1.00, CO2=273.00 -> Prediction: No fire detected.
# Data: Temperature=30.86, Humidity=30.65, Pressure=1015.70, CO=0.00, CO2=278.00 -> Prediction: No fire detected.
# Data: Temperature=30.88, Humidity=30.62, Pressure=1015.64, CO=0.00, CO2=281.00 -> Prediction: No fire detected.
# Data: Temperature=30.93, Humidity=30.65, Pressure=1015.70, CO=0.00, CO2=284.00 -> Prediction: No fire detected.
# Data: Temperature=30.97, Humidity=30.65, Pressure=1015.74, CO=0.00, CO2=286.00 -> Prediction: No fire detected.
# Data: Temperature=31.10, Humidity=30.58, Pressure=1015.69, CO=0.00, CO2=292.00 -> Prediction: No fire detected.
# Data: Temperature=31.18, Humidity=30.56, Pressure=1015.70, CO=0.00, CO2=294.00 -> Prediction: No fire detected.
# Data: Temperature=31.19, Humidity=30.53, Pressure=1015.72, CO=0.00, CO2=296.00 -> Prediction: No fire detected.
# Data: Temperature=31.20, Humidity=30.47, Pressure=1015.74, CO=0.00, CO2=298.00 -> Prediction: No fire detected.
# Data: Temperature=32.59, Humidity=29.55, Pressure=1015.65, CO=2.00, CO2=373.00 -> Prediction: No fire detected.
# Data: Temperature=32.46, Humidity=29.55, Pressure=1015.59, CO=2.00, CO2=372.00 -> Prediction: No fire detected.
# Data: Temperature=32.38, Humidity=29.56, Pressure=1015.66, CO=1.00, CO2=370.00 -> Prediction: No fire detected.
# Data: Temperature=32.17, Humidity=29.60, Pressure=1015.60, CO=0.00, CO2=364.00 -> Prediction: No fire detected.
# Data: Temperature=31.99, Humidity=29.50, Pressure=1015.65, CO=0.00, CO2=352.00 -> Prediction: No fire detected.
# Data: Temperature=31.92, Humidity=29.38, Pressure=1015.68, CO=0.00, CO2=346.00 -> Prediction: No fire detected.
# Data: Temperature=31.53, Humidity=29.51, Pressure=1015.63, CO=0.00, CO2=333.00 -> Prediction: No fire detected.
# Data: Temperature=31.47, Humidity=29.53, Pressure=1015.67, CO=1.00, CO2=331.00 -> Prediction: No fire detected.
# Data: Temperature=31.43, Humidity=29.61, Pressure=1015.71, CO=1.00, CO2=338.00 -> Prediction: No fire detected.
# Data: Temperature=31.28, Humidity=30.26, Pressure=1015.59, CO=1.00, CO2=357.00 -> Prediction: No fire detected.
# Data: Temperature=31.22, Humidity=30.25, Pressure=1015.60, CO=0.00, CO2=359.00 -> Prediction: No fire detected.
# Data: Temperature=31.07, Humidity=30.32, Pressure=1015.65, CO=0.00, CO2=358.00 -> Prediction: No fire detected.
# Data: Temperature=30.99, Humidity=30.51, Pressure=1015.63, CO=0.00, CO2=355.00 -> Prediction: No fire detected.
# Data: Temperature=30.95, Humidity=30.68, Pressure=1015.63, CO=0.00, CO2=355.00 -> Prediction: No fire detected.
# Data: Temperature=30.77, Humidity=30.83, Pressure=1015.61, CO=0.00, CO2=353.00 -> Prediction: No fire detected.
# Data: Temperature=30.65, Humidity=30.79, Pressure=1015.64, CO=0.00, CO2=350.00 -> Prediction: No fire detected.
# Data: Temperature=30.62, Humidity=30.91, Pressure=1015.64, CO=0.00, CO2=346.00 -> Prediction: No fire detected.
# Data: Temperature=30.54, Humidity=31.15, Pressure=1015.64, CO=0.00, CO2=343.00 -> Prediction: No fire detected.
# Data: Temperature=30.54, Humidity=31.16, Pressure=1015.67, CO=0.00, CO2=339.00 -> Prediction: No fire detected.
# Data: Temperature=30.48, Humidity=31.04, Pressure=1015.59, CO=0.00, CO2=335.00 -> Prediction: No fire detected.
# Data: Temperature=30.39, Humidity=30.98, Pressure=1015.62, CO=0.00, CO2=331.00 -> Prediction: Fire detected!
# Data: Temperature=30.32, Humidity=31.02, Pressure=1015.62, CO=0.00, CO2=328.00 -> Prediction: Fire detected!
# Data: Temperature=30.25, Humidity=31.13, Pressure=1015.62, CO=0.00, CO2=326.00 -> Prediction: Fire detected!
# Data: Temperature=30.20, Humidity=31.49, Pressure=1015.65, CO=0.00, CO2=323.00 -> Prediction: Fire detected!
# Data: Temperature=30.15, Humidity=31.67, Pressure=1015.63, CO=0.00, CO2=323.00 -> Prediction: Fire detected!
# Data: Temperature=29.88, Humidity=31.53, Pressure=1015.59, CO=0.00, CO2=321.00 -> Prediction: Fire detected!
# Data: Temperature=29.54, Humidity=31.48, Pressure=1015.55, CO=0.00, CO2=319.00 -> Prediction: No fire detected.
# Data: Temperature=29.45, Humidity=31.76, Pressure=1015.58, CO=0.00, CO2=317.00 -> Prediction: No fire detected.
# Data: Temperature=29.38, Humidity=31.89, Pressure=1015.62, CO=0.00, CO2=316.00 -> Prediction: No fire detected.
# Data: Temperature=29.34, Humidity=31.99, Pressure=1015.71, CO=0.00, CO2=316.00 -> Prediction: No fire detected.
# Data: Temperature=29.27, Humidity=32.11, Pressure=1015.68, CO=0.00, CO2=317.00 -> Prediction: No fire detected.
# Data: Temperature=29.25, Humidity=32.21, Pressure=1015.70, CO=0.00, CO2=317.00 -> Prediction: No fire detected.
# Data: Temperature=29.12, Humidity=32.23, Pressure=1015.72, CO=0.00, CO2=317.00 -> Prediction: No fire detected.
# Data: Temperature=29.02, Humidity=32.32, Pressure=1015.62, CO=0.00, CO2=318.00 -> Prediction: No fire detected.
# Data: Temperature=29.02, Humidity=32.31, Pressure=1015.67, CO=0.00, CO2=317.00 -> Prediction: No fire detected.
# Data: Temperature=28.95, Humidity=32.39, Pressure=1015.67, CO=0.00, CO2=316.00 -> Prediction: No fire detected.
# Data: Temperature=28.87, Humidity=32.38, Pressure=1015.60, CO=0.00, CO2=314.00 -> Prediction: No fire detected.
# Data: Temperature=28.80, Humidity=32.39, Pressure=1015.62, CO=0.00, CO2=313.00 -> Prediction: No fire detected.
# Data: Temperature=28.71, Humidity=32.43, Pressure=1015.67, CO=0.00, CO2=310.00 -> Prediction: No fire detected.
# Data: Temperature=28.52, Humidity=32.61, Pressure=1015.68, CO=0.00, CO2=307.00 -> Prediction: No fire detected.
# Data: Temperature=28.42, Humidity=32.72, Pressure=1015.62, CO=0.00, CO2=305.00 -> Prediction: No fire detected.
# Data: Temperature=28.30, Humidity=32.77, Pressure=1015.57, CO=0.00, CO2=303.00 -> Prediction: No fire detected.
# Data: Temperature=23.17, Humidity=38.73, Pressure=1015.41, CO=0.00, CO2=319.00 -> Prediction: No fire detected.
# Data: Temperature=23.10, Humidity=38.87, Pressure=1015.40, CO=0.00, CO2=320.00 -> Prediction: No fire detected.
# Data: Temperature=23.01, Humidity=39.00, Pressure=1015.42, CO=0.00, CO2=320.00 -> Prediction: No fire detected.
# Data: Temperature=22.76, Humidity=39.30, Pressure=1015.45, CO=0.00, CO2=321.00 -> Prediction: No fire detected.
# Data: Temperature=22.71, Humidity=39.52, Pressure=1015.51, CO=0.00, CO2=320.00 -> Prediction: No fire detected.
# Data: Temperature=22.65, Humidity=39.70, Pressure=1015.59, CO=0.00, CO2=319.00 -> Prediction: No fire detected.
# Data: Temperature=22.60, Humidity=39.89, Pressure=1015.54, CO=0.00, CO2=318.00 -> Prediction: No fire detected.
# Data: Temperature=22.52, Humidity=40.16, Pressure=1015.51, CO=0.00, CO2=317.00 -> Prediction: No fire detected.
# Data: Temperature=22.44, Humidity=40.38, Pressure=1015.49, CO=0.00, CO2=318.00 -> Prediction: No fire detected.
# Data: Temperature=22.40, Humidity=40.50, Pressure=1015.57, CO=0.00, CO2=319.00 -> Prediction: No fire detected.
# Data: Temperature=21.01, Humidity=42.96, Pressure=1015.46, CO=0.00, CO2=359.00 -> Prediction: No fire detected.
# Data: Temperature=20.92, Humidity=43.09, Pressure=1015.47, CO=0.00, CO2=343.00 -> Prediction: No fire detected.
# Data: Temperature=20.82, Humidity=43.22, Pressure=1015.36, CO=0.00, CO2=331.00 -> Prediction: No fire detected.
# Data: Temperature=20.80, Humidity=43.32, Pressure=1015.42, CO=0.00, CO2=322.00 -> Prediction: No fire detected.
# Data: Temperature=20.75, Humidity=43.56, Pressure=1015.37, CO=0.00, CO2=321.00 -> Prediction: No fire detected.
# Data: Temperature=20.72, Humidity=43.61, Pressure=1015.35, CO=0.00, CO2=318.00 -> Prediction: No fire detected.
# Data: Temperature=20.71, Humidity=43.66, Pressure=1015.39, CO=0.00, CO2=317.00 -> Prediction: No fire detected.
# Data: Temperature=20.70, Humidity=43.75, Pressure=1015.35, CO=0.00, CO2=316.00 -> Prediction: No fire detected.
# Data: Temperature=20.70, Humidity=43.83, Pressure=1015.43, CO=0.00, CO2=316.00 -> Prediction: No fire detected.
# Data: Temperature=20.69, Humidity=43.94, Pressure=1015.32, CO=0.00, CO2=316.00 -> Prediction: No fire detected.
# Data: Temperature=20.65, Humidity=44.02, Pressure=1015.46, CO=0.00, CO2=316.00 -> Prediction: No fire detected.
# Data: Temperature=20.58, Humidity=43.96, Pressure=1015.42, CO=0.00, CO2=314.00 -> Prediction: No fire detected.
# Data: Temperature=20.55, Humidity=43.94, Pressure=1015.40, CO=0.00, CO2=314.00 -> Prediction: No fire detected.
# Data: Temperature=20.50, Humidity=44.00, Pressure=1015.43, CO=0.00, CO2=314.00 -> Prediction: No fire detected.
# Data: Temperature=20.50, Humidity=44.00, Pressure=1015.43, CO=0.00, CO2=314.00 -> Prediction: No fire detected.
# Data: Temperature=20.50, Humidity=44.14, Pressure=1015.38, CO=0.00, CO2=314.00 -> Prediction: No fire detected.
# Data: Temperature=20.51, Humidity=44.19, Pressure=1015.39, CO=0.00, CO2=314.00 -> Prediction: No fire detected.
# Data: Temperature=20.51, Humidity=44.22, Pressure=1015.36, CO=0.00, CO2=313.00 -> Prediction: No fire detected.
# Data: Temperature=20.51, Humidity=44.20, Pressure=1015.31, CO=0.00, CO2=313.00 -> Prediction: No fire detected.
# Data: Temperature=20.51, Humidity=44.18, Pressure=1015.42, CO=0.00, CO2=313.00 -> Prediction: No fire detected.
# Data: Temperature=20.52, Humidity=44.18, Pressure=1015.38, CO=0.00, CO2=312.00 -> Prediction: No fire detected.
# Data: Temperature=20.51, Humidity=44.17, Pressure=1015.42, CO=0.00, CO2=311.00 -> Prediction: No fire detected.
# Data: Temperature=20.51, Humidity=44.19, Pressure=1015.44, CO=0.00, CO2=311.00 -> Prediction: No fire detected.
# Data: Temperature=20.51, Humidity=44.29, Pressure=1015.34, CO=0.00, CO2=311.00 -> Prediction: No fire detected.
# Data: Temperature=20.51, Humidity=44.38, Pressure=1015.45, CO=0.00, CO2=311.00 -> Prediction: No fire detected.
# Data: Temperature=20.53, Humidity=44.42, Pressure=1015.42, CO=0.00, CO2=311.00 -> Prediction: No fire detected.
# Data: Temperature=20.53, Humidity=44.51, Pressure=1015.51, CO=0.00, CO2=310.00 -> Prediction: No fire detected.
# Data: Temperature=20.55, Humidity=44.55, Pressure=1015.46, CO=0.00, CO2=311.00 -> Prediction: No fire detected.
# Data: Temperature=20.54, Humidity=44.59, Pressure=1015.37, CO=0.00, CO2=311.00 -> Prediction: No fire detected.
# Data: Temperature=20.56, Humidity=44.61, Pressure=1015.44, CO=0.00, CO2=310.00 -> Prediction: No fire detected.
# Data: Temperature=20.56, Humidity=44.52, Pressure=1015.45, CO=0.00, CO2=309.00 -> Prediction: No fire detected.
# Data: Temperature=20.57, Humidity=44.47, Pressure=1015.46, CO=0.00, CO2=309.00 -> Prediction: No fire detected.
# Data: Temperature=20.55, Humidity=44.35, Pressure=1015.51, CO=0.00, CO2=309.00 -> Prediction: No fire detected.
# Data: Temperature=20.51, Humidity=44.28, Pressure=1015.47, CO=0.00, CO2=309.00 -> Prediction: No fire detected.
# Data: Temperature=20.50, Humidity=44.25, Pressure=1015.41, CO=0.00, CO2=310.00 -> Prediction: No fire detected.
# Data: Temperature=20.50, Humidity=44.06, Pressure=1015.40, CO=0.00, CO2=309.00 -> Prediction: No fire detected.
# Data: Temperature=20.50, Humidity=43.87, Pressure=1015.37, CO=0.00, CO2=310.00 -> Prediction: No fire detected.
# Data: Temperature=20.50, Humidity=43.79, Pressure=1015.44, CO=0.00, CO2=309.00 -> Prediction: No fire detected.
# Data: Temperature=20.49, Humidity=43.81, Pressure=1015.39, CO=0.00, CO2=309.00 -> Prediction: No fire detected.
# Data: Temperature=20.47, Humidity=43.87, Pressure=1015.39, CO=0.00, CO2=309.00 -> Prediction: No fire detected.
# Data: Temperature=20.46, Humidity=43.93, Pressure=1015.34, CO=0.00, CO2=310.00 -> Prediction: No fire detected.
# Data: Temperature=20.47, Humidity=43.99, Pressure=1015.41, CO=0.00, CO2=310.00 -> Prediction: No fire detected.
# Data: Temperature=20.46, Humidity=44.09, Pressure=1015.45, CO=0.00, CO2=310.00 -> Prediction: No fire detected.
# Data: Temperature=20.43, Humidity=44.17, Pressure=1015.50, CO=0.00, CO2=310.00 -> Prediction: No fire detected.
# Data: Temperature=20.39, Humidity=44.19, Pressure=1015.42, CO=0.00, CO2=310.00 -> Prediction: No fire detected.
# Data: Temperature=20.37, Humidity=44.23, Pressure=1015.42, CO=0.00, CO2=310.00 -> Prediction: No fire detected.
# Data: Temperature=20.34, Humidity=44.28, Pressure=1015.45, CO=0.00, CO2=310.00 -> Prediction: No fire detected.
# Data: Temperature=20.33, Humidity=44.34, Pressure=1015.44, CO=0.00, CO2=310.00 -> Prediction: No fire detected.
# Data: Temperature=20.31, Humidity=44.39, Pressure=1015.43, CO=0.00, CO2=310.00 -> Prediction: No fire detected.
# Data: Temperature=20.31, Humidity=44.41, Pressure=1015.45, CO=0.00, CO2=310.00 -> Prediction: No fire detected.
# Data: Temperature=20.24, Humidity=44.37, Pressure=1015.32, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=20.30, Humidity=44.37, Pressure=1015.50, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=20.30, Humidity=44.38, Pressure=1015.50, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=20.32, Humidity=44.21, Pressure=1015.44, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=20.32, Humidity=44.21, Pressure=1015.52, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=20.31, Humidity=44.19, Pressure=1015.43, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=20.33, Humidity=44.16, Pressure=1015.46, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=20.30, Humidity=44.13, Pressure=1015.44, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=20.34, Humidity=44.09, Pressure=1015.40, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=20.34, Humidity=43.97, Pressure=1015.50, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=20.34, Humidity=43.90, Pressure=1015.43, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=20.36, Humidity=43.79, Pressure=1015.42, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=20.37, Humidity=43.46, Pressure=1015.45, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=20.38, Humidity=43.43, Pressure=1015.44, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=20.39, Humidity=43.35, Pressure=1015.45, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=20.41, Humidity=43.35, Pressure=1015.47, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=20.41, Humidity=43.40, Pressure=1015.37, CO=0.00, CO2=401.00 -> Prediction: No fire detected.
# Data: Temperature=20.42, Humidity=43.46, Pressure=1015.36, CO=0.00, CO2=401.00 -> Prediction: No fire detected.
# Data: Temperature=20.43, Humidity=43.53, Pressure=1015.37, CO=0.00, CO2=401.00 -> Prediction: No fire detected.
# Data: Temperature=20.44, Humidity=43.65, Pressure=1015.44, CO=0.00, CO2=402.00 -> Prediction: No fire detected.
# Data: Temperature=20.45, Humidity=43.70, Pressure=1015.37, CO=0.00, CO2=403.00 -> Prediction: No fire detected.
# Data: Temperature=20.44, Humidity=43.75, Pressure=1015.47, CO=0.00, CO2=404.00 -> Prediction: No fire detected.
# Data: Temperature=20.45, Humidity=43.67, Pressure=1015.40, CO=0.00, CO2=404.00 -> Prediction: No fire detected.
# Data: Temperature=20.45, Humidity=43.61, Pressure=1015.46, CO=0.00, CO2=406.00 -> Prediction: No fire detected.
# Data: Temperature=20.46, Humidity=43.66, Pressure=1015.36, CO=0.00, CO2=406.00 -> Prediction: No fire detected.
# Data: Temperature=20.46, Humidity=43.75, Pressure=1015.42, CO=0.00, CO2=406.00 -> Prediction: No fire detected.
# Data: Temperature=20.47, Humidity=43.85, Pressure=1015.41, CO=0.00, CO2=407.00 -> Prediction: No fire detected.
# Data: Temperature=20.50, Humidity=44.22, Pressure=1015.44, CO=0.00, CO2=408.00 -> Prediction: No fire detected.
# Data: Temperature=20.49, Humidity=44.31, Pressure=1015.39, CO=0.00, CO2=409.00 -> Prediction: No fire detected.
# Data: Temperature=20.50, Humidity=44.37, Pressure=1015.38, CO=0.00, CO2=410.00 -> Prediction: No fire detected.
# Data: Temperature=20.51, Humidity=44.40, Pressure=1015.36, CO=0.00, CO2=411.00 -> Prediction: No fire detected.
# Data: Temperature=20.53, Humidity=44.46, Pressure=1015.38, CO=0.00, CO2=410.00 -> Prediction: No fire detected.
# Data: Temperature=20.56, Humidity=44.59, Pressure=1015.44, CO=0.00, CO2=410.00 -> Prediction: No fire detected.
# Data: Temperature=20.58, Humidity=44.82, Pressure=1015.37, CO=0.00, CO2=410.00 -> Prediction: No fire detected.
# Data: Temperature=20.60, Humidity=45.17, Pressure=1015.37, CO=0.00, CO2=413.00 -> Prediction: No fire detected.
# Data: Temperature=20.62, Humidity=45.35, Pressure=1015.41, CO=0.00, CO2=413.00 -> Prediction: No fire detected.
# Data: Temperature=20.63, Humidity=45.44, Pressure=1015.48, CO=0.00, CO2=414.00 -> Prediction: No fire detected.
# Data: Temperature=20.64, Humidity=45.47, Pressure=1015.44, CO=0.00, CO2=416.00 -> Prediction: No fire detected.
# Data: Temperature=20.66, Humidity=45.60, Pressure=1015.53, CO=0.00, CO2=418.00 -> Prediction: No fire detected.
# Data: Temperature=20.67, Humidity=46.08, Pressure=1015.49, CO=0.00, CO2=422.00 -> Prediction: No fire detected.
# Data: Temperature=20.68, Humidity=46.38, Pressure=1015.42, CO=0.00, CO2=424.00 -> Prediction: No fire detected.
# Data: Temperature=20.72, Humidity=46.74, Pressure=1015.49, CO=0.00, CO2=429.00 -> Prediction: No fire detected.
# Data: Temperature=20.76, Humidity=46.82, Pressure=1015.44, CO=0.00, CO2=434.00 -> Prediction: No fire detected.
# Data: Temperature=20.79, Humidity=46.82, Pressure=1015.48, CO=0.00, CO2=435.00 -> Prediction: No fire detected.
# Data: Temperature=20.80, Humidity=46.74, Pressure=1015.39, CO=0.00, CO2=436.00 -> Prediction: No fire detected.
# Data: Temperature=20.82, Humidity=46.64, Pressure=1015.45, CO=0.00, CO2=437.00 -> Prediction: No fire detected.
# Data: Temperature=20.84, Humidity=46.47, Pressure=1015.51, CO=0.00, CO2=437.00 -> Prediction: No fire detected.
# Data: Temperature=20.87, Humidity=46.45, Pressure=1015.50, CO=0.00, CO2=437.00 -> Prediction: No fire detected.
# Data: Temperature=20.88, Humidity=46.45, Pressure=1015.53, CO=0.00, CO2=437.00 -> Prediction: No fire detected.
# Data: Temperature=20.90, Humidity=46.55, Pressure=1015.45, CO=0.00, CO2=436.00 -> Prediction: No fire detected.
# Data: Temperature=20.93, Humidity=46.60, Pressure=1015.46, CO=0.00, CO2=436.00 -> Prediction: No fire detected.
# Data: Temperature=20.94, Humidity=46.49, Pressure=1015.46, CO=0.00, CO2=436.00 -> Prediction: No fire detected.
# Data: Temperature=20.95, Humidity=46.25, Pressure=1015.52, CO=0.00, CO2=433.00 -> Prediction: No fire detected.
# Data: Temperature=20.95, Humidity=46.34, Pressure=1015.50, CO=128.00, CO2=449.00 -> Prediction: No fire detected.
# Data: Temperature=20.99, Humidity=47.40, Pressure=1015.53, CO=248.00, CO2=471.00 -> Prediction: No fire detected.
# Data: Temperature=21.01, Humidity=47.61, Pressure=1015.51, CO=176.00, CO2=477.00 -> Prediction: No fire detected.
# Data: Temperature=21.03, Humidity=47.71, Pressure=1015.52, CO=151.00, CO2=480.00 -> Prediction: No fire detected.
# Data: Temperature=21.08, Humidity=47.89, Pressure=1015.49, CO=166.00, CO2=486.00 -> Prediction: No fire detected.
# Data: Temperature=21.13, Humidity=47.68, Pressure=1015.44, CO=159.00, CO2=519.00 -> Prediction: No fire detected.
# Data: Temperature=21.14, Humidity=47.56, Pressure=1015.48, CO=125.00, CO2=536.00 -> Prediction: No fire detected.
# Data: Temperature=21.19, Humidity=47.51, Pressure=1015.53, CO=264.00, CO2=561.00 -> Prediction: No fire detected.
# Data: Temperature=21.25, Humidity=47.63, Pressure=1015.51, CO=364.00, CO2=619.00 -> Prediction: No fire detected.
# Data: Temperature=21.32, Humidity=47.89, Pressure=1015.51, CO=277.00, CO2=720.00 -> Prediction: No fire detected.
# Data: Temperature=21.39, Humidity=47.79, Pressure=1015.52, CO=157.00, CO2=774.00 -> Prediction: No fire detected.
# Data: Temperature=21.43, Humidity=47.61, Pressure=1015.50, CO=128.00, CO2=799.00 -> Prediction: No fire detected.
# Data: Temperature=21.48, Humidity=47.42, Pressure=1015.45, CO=152.00, CO2=821.00 -> Prediction: No fire detected.
# Data: Temperature=21.53, Humidity=47.05, Pressure=1015.43, CO=85.00, CO2=820.00 -> Prediction: No fire detected.
# Data: Temperature=21.62, Humidity=46.70, Pressure=1015.47, CO=64.00, CO2=828.00 -> Prediction: No fire detected.
# Data: Temperature=23.11, Humidity=42.59, Pressure=1015.49, CO=0.00, CO2=1097.00 -> Prediction: No fire detected.
# Data: Temperature=23.10, Humidity=42.55, Pressure=1015.47, CO=1.00, CO2=1014.00 -> Prediction: No fire detected.
# Data: Temperature=23.09, Humidity=42.51, Pressure=1015.44, CO=1.00, CO2=947.00 -> Prediction: No fire detected.
# Data: Temperature=23.08, Humidity=42.54, Pressure=1015.47, CO=0.00, CO2=886.00 -> Prediction: No fire detected.
# Data: Temperature=23.08, Humidity=42.61, Pressure=1015.48, CO=0.00, CO2=832.00 -> Prediction: No fire detected.
# Data: Temperature=23.07, Humidity=42.60, Pressure=1015.38, CO=0.00, CO2=783.00 -> Prediction: No fire detected.
# Data: Temperature=23.06, Humidity=42.61, Pressure=1015.50, CO=0.00, CO2=740.00 -> Prediction: No fire detected.
# Data: Temperature=23.06, Humidity=42.61, Pressure=1015.46, CO=0.00, CO2=698.00 -> Prediction: No fire detected.
# Data: Temperature=23.04, Humidity=42.51, Pressure=1015.49, CO=0.00, CO2=663.00 -> Prediction: No fire detected.
# Data: Temperature=23.04, Humidity=42.37, Pressure=1015.44, CO=0.00, CO2=631.00 -> Prediction: No fire detected.
# Data: Temperature=23.01, Humidity=42.21, Pressure=1015.48, CO=0.00, CO2=605.00 -> Prediction: No fire detected.
# Data: Temperature=22.98, Humidity=42.17, Pressure=1015.46, CO=0.00, CO2=557.00 -> Prediction: No fire detected.
# Data: Temperature=22.94, Humidity=41.95, Pressure=1015.45, CO=0.00, CO2=538.00 -> Prediction: No fire detected.
# Data: Temperature=22.95, Humidity=41.79, Pressure=1015.51, CO=0.00, CO2=521.00 -> Prediction: No fire detected.
# Data: Temperature=22.95, Humidity=41.61, Pressure=1015.51, CO=0.00, CO2=506.00 -> Prediction: No fire detected.
# Data: Temperature=22.91, Humidity=41.32, Pressure=1015.45, CO=0.00, CO2=481.00 -> Prediction: No fire detected.
# Data: Temperature=22.89, Humidity=41.19, Pressure=1015.44, CO=0.00, CO2=471.00 -> Prediction: No fire detected.
# Data: Temperature=22.85, Humidity=41.13, Pressure=1015.45, CO=0.00, CO2=462.00 -> Prediction: No fire detected.
# Data: Temperature=22.84, Humidity=41.12, Pressure=1015.42, CO=0.00, CO2=455.00 -> Prediction: No fire detected.
# Data: Temperature=22.83, Humidity=41.10, Pressure=1015.47, CO=0.00, CO2=447.00 -> Prediction: No fire detected.
# Data: Temperature=22.82, Humidity=41.17, Pressure=1015.42, CO=0.00, CO2=441.00 -> Prediction: No fire detected.
# Data: Temperature=22.79, Humidity=41.24, Pressure=1015.40, CO=0.00, CO2=437.00 -> Prediction: No fire detected.
# Data: Temperature=22.78, Humidity=41.30, Pressure=1015.40, CO=0.00, CO2=432.00 -> Prediction: No fire detected.
# Data: Temperature=22.71, Humidity=41.32, Pressure=1015.48, CO=0.00, CO2=429.00 -> Prediction: No fire detected.
# Data: Temperature=22.69, Humidity=41.31, Pressure=1015.40, CO=0.00, CO2=426.00 -> Prediction: No fire detected.
# Data: Temperature=22.69, Humidity=41.27, Pressure=1015.43, CO=0.00, CO2=422.00 -> Prediction: No fire detected.
# Data: Temperature=22.66, Humidity=41.29, Pressure=1015.46, CO=0.00, CO2=419.00 -> Prediction: No fire detected.
# Data: Temperature=22.65, Humidity=41.31, Pressure=1015.48, CO=0.00, CO2=416.00 -> Prediction: No fire detected.
# Data: Temperature=22.60, Humidity=41.39, Pressure=1015.43, CO=0.00, CO2=414.00 -> Prediction: No fire detected.
# Data: Temperature=22.63, Humidity=41.48, Pressure=1015.48, CO=0.00, CO2=412.00 -> Prediction: No fire detected.
# Data: Temperature=22.62, Humidity=41.54, Pressure=1015.46, CO=0.00, CO2=408.00 -> Prediction: No fire detected.
# Data: Temperature=22.59, Humidity=41.61, Pressure=1015.49, CO=0.00, CO2=405.00 -> Prediction: No fire detected.
# Data: Temperature=22.57, Humidity=41.69, Pressure=1015.46, CO=0.00, CO2=403.00 -> Prediction: No fire detected.
# Data: Temperature=22.57, Humidity=41.73, Pressure=1015.48, CO=0.00, CO2=400.00 -> Prediction: No fire detected.
# Data: Temperature=22.54, Humidity=41.66, Pressure=1015.46, CO=0.00, CO2=397.00 -> Prediction: No fire detected.
# Data: Temperature=22.52, Humidity=41.84, Pressure=1015.37, CO=0.00, CO2=395.00 -> Prediction: No fire detected.
# Data: Temperature=22.49, Humidity=42.04, Pressure=1015.44, CO=0.00, CO2=393.00 -> Prediction: No fire detected.
# Data: Temperature=22.50, Humidity=42.36, Pressure=1015.46, CO=1.00, CO2=398.00 -> Prediction: No fire detected.
# Data: Temperature=22.52, Humidity=42.65, Pressure=1015.45, CO=25.00, CO2=407.00 -> Prediction: No fire detected.
# Data: Temperature=22.52, Humidity=42.95, Pressure=1015.37, CO=17.00, CO2=415.00 -> Prediction: No fire detected.
# Data: Temperature=22.51, Humidity=43.01, Pressure=1015.44, CO=9.00, CO2=420.00 -> Prediction: No fire detected.
# Data: Temperature=22.51, Humidity=42.98, Pressure=1015.41, CO=2.00, CO2=421.00 -> Prediction: No fire detected.
# Data: Temperature=22.52, Humidity=42.96, Pressure=1015.46, CO=25.00, CO2=443.00 -> Prediction: No fire detected.
# Data: Temperature=22.53, Humidity=42.95, Pressure=1015.45, CO=30.00, CO2=458.00 -> Prediction: No fire detected.
# Data: Temperature=22.51, Humidity=42.76, Pressure=1015.41, CO=37.00, CO2=464.00 -> Prediction: No fire detected.
# Data: Temperature=22.51, Humidity=42.56, Pressure=1015.42, CO=76.00, CO2=492.00 -> Prediction: No fire detected.
# Data: Temperature=22.49, Humidity=42.48, Pressure=1015.38, CO=88.00, CO2=507.00 -> Prediction: No fire detected.
# Data: Temperature=22.50, Humidity=42.41, Pressure=1015.47, CO=54.00, CO2=513.00 -> Prediction: No fire detected.
# Data: Temperature=22.48, Humidity=42.39, Pressure=1015.40, CO=38.00, CO2=522.00 -> Prediction: No fire detected.
# Data: Temperature=22.50, Humidity=42.41, Pressure=1015.42, CO=40.00, CO2=537.00 -> Prediction: No fire detected.
# Data: Temperature=22.49, Humidity=42.49, Pressure=1015.49, CO=64.00, CO2=548.00 -> Prediction: No fire detected.
# Data: Temperature=22.49, Humidity=42.54, Pressure=1015.43, CO=69.00, CO2=567.00 -> Prediction: No fire detected.
# Data: Temperature=22.50, Humidity=42.58, Pressure=1015.43, CO=74.00, CO2=593.00 -> Prediction: No fire detected.
# Data: Temperature=22.51, Humidity=42.58, Pressure=1015.46, CO=36.00, CO2=601.00 -> Prediction: No fire detected.
# Data: Temperature=22.49, Humidity=42.49, Pressure=1015.47, CO=18.00, CO2=602.00 -> Prediction: No fire detected.
# Data: Temperature=22.51, Humidity=42.40, Pressure=1015.44, CO=10.00, CO2=599.00 -> Prediction: No fire detected.
# Data: Temperature=22.49, Humidity=42.39, Pressure=1015.43, CO=4.00, CO2=596.00 -> Prediction: No fire detected.
# Data: Temperature=22.50, Humidity=42.37, Pressure=1015.45, CO=2.00, CO2=590.00 -> Prediction: No fire detected.
# Data: Temperature=22.51, Humidity=42.36, Pressure=1015.50, CO=2.00, CO2=580.00 -> Prediction: No fire detected.
# Data: Temperature=22.53, Humidity=42.27, Pressure=1015.44, CO=11.00, CO2=571.00 -> Prediction: No fire detected.
# Data: Temperature=22.52, Humidity=42.20, Pressure=1015.43, CO=13.00, CO2=565.00 -> Prediction: No fire detected.
# Data: Temperature=22.53, Humidity=42.19, Pressure=1015.42, CO=23.00, CO2=580.00 -> Prediction: No fire detected.
# Data: Temperature=22.53, Humidity=42.40, Pressure=1015.44, CO=17.00, CO2=588.00 -> Prediction: No fire detected.
# Data: Temperature=22.55, Humidity=42.60, Pressure=1015.42, CO=17.00, CO2=596.00 -> Prediction: No fire detected.
# Data: Temperature=22.56, Humidity=42.66, Pressure=1015.46, CO=23.00, CO2=606.00 -> Prediction: No fire detected.
# Data: Temperature=22.56, Humidity=42.73, Pressure=1015.46, CO=17.00, CO2=606.00 -> Prediction: No fire detected.
# Data: Temperature=22.56, Humidity=42.76, Pressure=1015.44, CO=9.00, CO2=598.00 -> Prediction: No fire detected.
# Data: Temperature=22.57, Humidity=42.69, Pressure=1015.49, CO=4.00, CO2=585.00 -> Prediction: No fire detected.
# Data: Temperature=22.57, Humidity=42.69, Pressure=1015.45, CO=1.00, CO2=572.00 -> Prediction: No fire detected.
# Data: Temperature=22.57, Humidity=42.63, Pressure=1015.41, CO=0.00, CO2=558.00 -> Prediction: No fire detected.
# Data: Temperature=22.56, Humidity=42.53, Pressure=1015.46, CO=0.00, CO2=545.00 -> Prediction: No fire detected.
# Data: Temperature=22.56, Humidity=42.41, Pressure=1015.46, CO=0.00, CO2=532.00 -> Prediction: No fire detected.
# Data: Temperature=22.56, Humidity=42.24, Pressure=1015.42, CO=0.00, CO2=519.00 -> Prediction: No fire detected.
# Data: Temperature=22.55, Humidity=42.28, Pressure=1015.37, CO=0.00, CO2=507.00 -> Prediction: No fire detected.
# Data: Temperature=22.53, Humidity=42.39, Pressure=1015.42, CO=0.00, CO2=496.00 -> Prediction: No fire detected.
# Data: Temperature=22.51, Humidity=42.58, Pressure=1015.46, CO=0.00, CO2=486.00 -> Prediction: No fire detected.
# Data: Temperature=22.46, Humidity=42.84, Pressure=1015.42, CO=0.00, CO2=477.00 -> Prediction: No fire detected.
# Data: Temperature=22.45, Humidity=43.03, Pressure=1015.37, CO=0.00, CO2=473.00 -> Prediction: No fire detected.
# Data: Temperature=22.45, Humidity=43.09, Pressure=1015.46, CO=6.00, CO2=473.00 -> Prediction: No fire detected.
# Data: Temperature=22.44, Humidity=43.13, Pressure=1015.47, CO=3.00, CO2=475.00 -> Prediction: No fire detected.
# Data: Temperature=22.45, Humidity=43.24, Pressure=1015.37, CO=2.00, CO2=475.00 -> Prediction: No fire detected.
# Data: Temperature=22.43, Humidity=43.45, Pressure=1015.43, CO=1.00, CO2=475.00 -> Prediction: No fire detected.
# Data: Temperature=22.43, Humidity=43.57, Pressure=1015.45, CO=0.00, CO2=474.00 -> Prediction: No fire detected.
# Data: Temperature=22.44, Humidity=43.65, Pressure=1015.41, CO=0.00, CO2=471.00 -> Prediction: No fire detected.
# Data: Temperature=22.45, Humidity=43.76, Pressure=1015.43, CO=0.00, CO2=469.00 -> Prediction: No fire detected.
# Data: Temperature=22.44, Humidity=43.80, Pressure=1015.50, CO=9.00, CO2=472.00 -> Prediction: No fire detected.
# Data: Temperature=22.42, Humidity=43.71, Pressure=1015.36, CO=10.00, CO2=473.00 -> Prediction: No fire detected.
# Data: Temperature=22.43, Humidity=43.64, Pressure=1015.40, CO=3.00, CO2=471.00 -> Prediction: No fire detected.
# Data: Temperature=22.44, Humidity=43.53, Pressure=1015.38, CO=0.00, CO2=468.00 -> Prediction: No fire detected.
# Data: Temperature=22.42, Humidity=43.33, Pressure=1015.46, CO=0.00, CO2=464.00 -> Prediction: No fire detected.
# Data: Temperature=22.40, Humidity=43.19, Pressure=1015.46, CO=0.00, CO2=460.00 -> Prediction: No fire detected.
# Data: Temperature=22.39, Humidity=43.06, Pressure=1015.36, CO=0.00, CO2=456.00 -> Prediction: No fire detected.
# Data: Temperature=22.40, Humidity=43.08, Pressure=1015.40, CO=0.00, CO2=458.00 -> Prediction: No fire detected.
# Data: Temperature=22.39, Humidity=43.60, Pressure=1015.44, CO=0.00, CO2=480.00 -> Prediction: No fire detected.
# Data: Temperature=22.36, Humidity=43.95, Pressure=1015.34, CO=0.00, CO2=481.00 -> Prediction: No fire detected.
# Data: Temperature=22.34, Humidity=44.11, Pressure=1015.44, CO=0.00, CO2=479.00 -> Prediction: No fire detected.
# Data: Temperature=22.33, Humidity=44.29, Pressure=1015.37, CO=0.00, CO2=476.00 -> Prediction: No fire detected.
# Data: Temperature=22.30, Humidity=44.33, Pressure=1015.32, CO=0.00, CO2=467.00 -> Prediction: No fire detected.
# Data: Temperature=22.29, Humidity=44.16, Pressure=1015.47, CO=0.00, CO2=464.00 -> Prediction: No fire detected.
# Data: Temperature=22.27, Humidity=44.12, Pressure=1015.42, CO=0.00, CO2=460.00 -> Prediction: No fire detected.
# Data: Temperature=22.27, Humidity=44.16, Pressure=1015.42, CO=0.00, CO2=461.00 -> Prediction: No fire detected.
# Data: Temperature=22.24, Humidity=44.11, Pressure=1015.46, CO=0.00, CO2=460.00 -> Prediction: No fire detected.
# Data: Temperature=22.25, Humidity=44.08, Pressure=1015.41, CO=0.00, CO2=459.00 -> Prediction: No fire detected.
# Data: Temperature=22.24, Humidity=44.16, Pressure=1015.35, CO=0.00, CO2=462.00 -> Prediction: No fire detected.
# Data: Temperature=22.24, Humidity=44.18, Pressure=1015.39, CO=0.00, CO2=463.00 -> Prediction: No fire detected.
# Data: Temperature=22.25, Humidity=44.17, Pressure=1015.35, CO=0.00, CO2=462.00 -> Prediction: No fire detected.
# Data: Temperature=22.21, Humidity=44.08, Pressure=1015.38, CO=0.00, CO2=460.00 -> Prediction: No fire detected.
# Data: Temperature=22.08, Humidity=43.75, Pressure=1015.36, CO=0.00, CO2=454.00 -> Prediction: No fire detected.
# Data: Temperature=22.07, Humidity=43.66, Pressure=1015.30, CO=0.00, CO2=450.00 -> Prediction: No fire detected.
# Data: Temperature=22.05, Humidity=43.50, Pressure=1015.32, CO=0.00, CO2=447.00 -> Prediction: No fire detected.
# Data: Temperature=22.02, Humidity=43.40, Pressure=1015.26, CO=0.00, CO2=445.00 -> Prediction: No fire detected.
# Data: Temperature=22.01, Humidity=43.71, Pressure=1015.27, CO=0.00, CO2=459.00 -> Prediction: No fire detected.
# Data: Temperature=22.07, Humidity=43.81, Pressure=1015.29, CO=0.00, CO2=483.00 -> Prediction: No fire detected.
